# %%
import os
import pandas as pd
import numpy as np
from datasets import load_dataset
pd.set_option("display.max_colwidth", 200)

# %%
# Load the full dataset (all generation methods)
dataset = load_dataset("KFUPM-JRCAI/arabic-generated-abstracts")

# Inspect available splits
print(dataset)  # should show: by_polishing, from_title, from_title_and_content
# Out:
# DatasetDict({
#     by_polishing: Dataset({
#         features: ['original_abstract', 'allam_generated_abstract', 'jais_generated_abstract', 'llama_generated_abstract', 'openai_generated_abstract'],
#         num_rows: 2851
#     })
#     from_title: Dataset({
#         features: ['original_abstract', 'allam_generated_abstract', 'jais_generated_abstract', 'llama_generated_abstract', 'openai_generated_abstract'],
#         num_rows: 2963
#     })
#     from_title_and_content: Dataset({
#         features: ['original_abstract', 'allam_generated_abstract', 'jais_generated_abstract', 'llama_generated_abstract', 'openai_generated_abstract'],
#         num_rows: 2574
#     })
# })

# %%
# Convert one split to a pandas DataFrame
split_name = "by_polishing"
df = pd.DataFrame(dataset[split_name])
df.head()
# Out:
#                                                                                                                                                                                          original_abstract  \
# 0  كثيرا ما ارتبطت المصادر التاريخية في الأندلس خاصة منها كتب التراجم والفهرسات والبرامج وغيرها بدراسة حياة العلماء والرواة والقضاة والساسة ؛ وقد تطورت هذه المادة حتى ترك لنا المؤلفون الأندلسيون سلسل...
# 1  يعد العامل الثقافي احد ابرز الاسباب التي يعزى لها سقوط الدولة الموحدية ، حتى أنه لايقل من حيث التأثير عن بقية العوامل خاصة السياسية و العسكرية ، فالتركيب الفكري لعقيدة ابن تومرت التي اعتبرت الركيز...
# 2  شكلت تلك الجهود والمساعي الرائدة التي قام بها قادة الثورة خلال مرحلتها الأولى (1954-1956) للبحث عن مصادر لتمويل الثورة بالأسلحة والذخيرة سواء في الداخل انطلاقا من المناطق الحدودية الشرقية والغربية...
# 3  يقوم المقال على اشكالية الضرائب الغير شرعية في مختلف مراحل دولتي المرابطين والموحدين أي منذ القيام إلى السقوط، وأثرها على طبيعة علاقتهما مع الرعية. وقد وجدنا أن المرابطين قد تراجعوا عن مبدأ إلغاء ...
# 4  تتفق المصادر التاريخية المتوفرة حول موضوع تطور الحركة الوطنية الجزائرية بعد نهاية الحرب العالمية الثانية1945،على أن الأزمة المزمنة التي عصفت بهياكل (حركة الانتصار للحريات الديمقراطية)MTLD خلال مؤت...
#
#                                                                                                                                                                                   allam_generated_abstract  \
# 0  يتناول هذا البحث موضوع التعليم بين النساء الأندلسيات من خلال دراسة المصادر التاريخية المتعلقة بتراجم العلماء والرواة والقضاة والساسة. يركز البحث على إبراز دور المرأة العالمة ومساهمتها في الإنتاج ا...
# 1  يتناول هذا البحث دراسة انهيار دولة الموحدين من منظور الخلفيات الثقافية. يعتبر العامل الثقافي أحد الأسباب الرئيسية التي أدت إلى سقوط الدولة، حيث لا يقل تأثيره عن العوامل السياسية والعسكرية. ترتكز ا...
# 2  هدفت هذه الدراسة إلى تسليط الضوء على جهود قادة الثورة الجزائرية (1954-1962) في تأمين تسليح جيش التحرير الوطني عبر الحدود الغربية. خلال المرحلة الأولى (1954-1956)، سعى القادة للحصول على مصادر تمويل...
columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   original_abstract          2851 non-null   object
#  1   allam_generated_abstract   2851 non-null   object
#  2   jais_generated_abstract    2851 non-null   object
#  3   llama_generated_abstract   2851 non-null   object
#  4   openai_generated_abstract  2851 non-null   object
# dtypes: object(5)
# memory usage: 111.5+ KB
# None

# %%
ai_cols = [c for c in df.columns if c.endswith("_generated_abstract")]
print(ai_cols)
# Out:
# ['allam_generated_abstract', 'jais_generated_abstract', 'llama_generated_abstract', 'openai_generated_abstract']

# %%
human_df = df[["original_abstract"]].dropna().rename(columns={"original_abstract": "text"})
human_df["label"] = 0
human_df["source"] = "human"
human_df["split"]  = split_name

# %%
ai_frames = []
for c in ai_cols:
    tmp = df[[c]].dropna().rename(columns={c: "text"})
    if not tmp.empty:
        tmp["label"]  = 1
        tmp["source"] = c.replace("_generated_abstract","")
        tmp["split"]  = split_name
        ai_frames.append(tmp)

# %%
ai_df = pd.concat(ai_frames, ignore_index=True) if ai_frames else pd.DataFrame(columns=["text","label","source","split"])
combined = pd.concat([human_df, ai_df], ignore_index=True)

# %%
combined = combined.assign(text=combined["text"].astype(str).str.strip())
combined = combined[combined["text"]!=""].reset_index(drop=True)

# %%
combined.head(10)
# Out:
#                                                                                                                                                                                                       text  \
# 0  كثيرا ما ارتبطت المصادر التاريخية في الأندلس خاصة منها كتب التراجم والفهرسات والبرامج وغيرها بدراسة حياة العلماء والرواة والقضاة والساسة ؛ وقد تطورت هذه المادة حتى ترك لنا المؤلفون الأندلسيون سلسل...
# 1  يعد العامل الثقافي احد ابرز الاسباب التي يعزى لها سقوط الدولة الموحدية ، حتى أنه لايقل من حيث التأثير عن بقية العوامل خاصة السياسية و العسكرية ، فالتركيب الفكري لعقيدة ابن تومرت التي اعتبرت الركيز...
# 2  شكلت تلك الجهود والمساعي الرائدة التي قام بها قادة الثورة خلال مرحلتها الأولى (1954-1956) للبحث عن مصادر لتمويل الثورة بالأسلحة والذخيرة سواء في الداخل انطلاقا من المناطق الحدودية الشرقية والغربية...
# 3  يقوم المقال على اشكالية الضرائب الغير شرعية في مختلف مراحل دولتي المرابطين والموحدين أي منذ القيام إلى السقوط، وأثرها على طبيعة علاقتهما مع الرعية. وقد وجدنا أن المرابطين قد تراجعوا عن مبدأ إلغاء ...
# 4  تتفق المصادر التاريخية المتوفرة حول موضوع تطور الحركة الوطنية الجزائرية بعد نهاية الحرب العالمية الثانية1945،على أن الأزمة المزمنة التي عصفت بهياكل (حركة الانتصار للحريات الديمقراطية)MTLD خلال مؤت...
# 5  تعددت صور الحياة الثقافية و الفكرية و الأدبية في هذا العصر وارتبطت بواقعهم الحضاري الذي حدثت فيه طفرة نوعية كبيرة حين عد عصرهم بداية لازدهار ثقافي و علمي و أدبي لم يشهد له المغرب مثيلا من قبل، وهذ...
# 6  تروم هذه المحاولة العلمية المتواضعة رصد ملامح التحولات النضالية التي عرفتها الجزائر مع بزوغ القرن العشرين، حيث لجأ الجزائريون إلى تغيير نمط تصديهم للمحتلين الفرنسيين باستبدال طريقة المواجهة المسلح...
# 7  يعالج هذا المقال الإطار التنسيقي بين المنظمات الطلابية لكل من تونس والجزائر والمغرب الأقصى، والذي توج بظهور كونفدرالية الشمال الإفريقي للطلبة، والتي كان تأسيسها قد تزامن مع العديد من التطورات التي...
# 8  يتناول هذا المقال بالدرس، اقتصاد الأندلس المبني على الغزو في صورة غنائم تراوحت بين المنقولة (العينية) والغير منقولة (عقارات وغيرها من الملكيات)، وتمتد فترة الدراسة من سنة 91ه، باعتبارها بداية إرسا...
# 9  نعالج في هذا الموضوع المعنون ب«الثورة التحريرية بالجنوب الغربي الجزائري (المنطقة الثامنة من الولاية الخامسة) منطقة العين الصفراء – أنموذجا - شهادة حية للمجاهد خليفي بونوة (ملازم بجيش التحرير الوطن...
#
#    label source         split
# 0      0  human  by_polishing
# 1      0  human  by_polishing
# 2      0  human  by_polishing
# 3      0  human  by_polishing
# 4      0  human  by_polishing
# 5      0  human  by_polishing
# 6      0  human  by_polishing
# 7      0  human  by_polishing
# 8      0  human  by_polishing
# 9      0  human  by_polishing

# %%
print("Shape:", combined.shape)
print("Label counts:\n", combined["label"].value_counts())
print("Missing text:", combined["text"].isna().sum())
print("Duplicate rows (text,label):", combined.duplicated(subset=["text","label"]).sum())
# Out:
# Shape: (14255, 4)
# Label counts:
#  1    11404
# 0     2851
# Name: label, dtype: int64
# Missing text: 0
# Duplicate rows (text,label): 0

# %%
# save the data processed in folder processed
os.makedirs("../data/processed", exist_ok=True)
combined.to_csv("../data/processed/combined_by_polishing.csv", index=False)
print("Saved to ../data/processed/combined_by_polishing.csv")
# Out:
# Saved to ../data/processed/combined_by_polishing.csv

# %%
# All available splits
splits = ["by_polishing", "from_title", "from_title_and_content"]

# List to store all rows
all_dataframes = []

# %%
for split_name in splits:
    df = pd.DataFrame(dataset[split_name])
    
    # Identify AI-generated columns
    ai_cols = [c for c in df.columns if c.endswith("_generated_abstract")]

    # Human-written
    human_df = df[["original_abstract"]].dropna().rename(columns={"original_abstract": "text"})
    human_df["label"] = 0
    human_df["source"] = "human"
    human_df["split"]  = split_name

    # AI-generated
    ai_frames = []
    for c in ai_cols:
        tmp = df[[c]].dropna().rename(columns={c: "text"})
        if not tmp.empty:
            tmp["label"]  = 1
            tmp["source"] = c.replace("_generated_abstract", "")
            tmp["split"]  = split_name
            ai_frames.append(tmp)

    ai_df = pd.concat(ai_frames, ignore_index=True) if ai_frames else pd.DataFrame(columns=["text","label","source","split"])

    # Combine both
    combined_df = pd.concat([human_df, ai_df], ignore_index=True)
    combined_df = combined_df.assign(text=combined_df["text"].astype(str).str.strip())
    combined_df = combined_df[combined_df["text"] != ""].reset_index(drop=True)

    # Add to the main list
    all_dataframes.append(combined_df)

# %%
# Merge all splits into one DataFrame
full_df = pd.concat(all_dataframes, ignore_index=True)
print("Combined shape:", full_df.shape)
print(full_df["label"].value_counts())
# Out:
# Combined shape: (41940, 4)
# 1    33552
# 0     8388
# Name: label, dtype: int64

# %%
# Save to file
full_df.to_csv("../data/processed/combined_all.csv", index=False)
print("✅ Saved to: ../data/processed/combined_all.csv")
# Out:
# ✅ Saved to: ../data/processed/combined_all.csv

# %%
print("Shape:", full_df.shape)
print("Label counts:\n", full_df["label"].value_counts())
print("Missing text:", full_df["text"].isna().sum())
print("Duplicate rows (text,label):", full_df.duplicated(subset=["text","label"]).sum())
# Out:
# Shape: (41940, 4)
# Label counts:
#  1    33552
# 0     8388
# Name: label, dtype: int64
# Missing text: 0
# Duplicate rows (text,label): 5399
